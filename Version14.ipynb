# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
weekly_df = daily_df.resample('W', on='Order Date')['Total Profit'].sum().reset_index()
weekly_df.columns = ['Order Date', 'Total Profit']
weekly_df.set_index('Order Date', inplace=True)

# %%
Q1 = weekly_df['Total Profit'].quantile( 0.25)
Q3 = weekly_df['Total Profit'].quantile( 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
weekly_df = weekly_df[(weekly_df['Total Profit'] >= lower_bound) & 
                      (weekly_df['Total Profit'] <= upper_bound)]

# %%
train_data, test_data = train_test_split(weekly_df, test_size= 0.2, shuffle=False)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM( 100, return_sequences=True), input_shape=(seq_length, 1)),
    BatchNormalization(),
    Dropout(0.3),
    Bidirectional(LSTM( 100, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.3),
    Bidirectional(LSTM( 50)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(50, activation='relu'),
    Dense(1)
])

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 27/27 [==============================] - 10s 86ms/step - loss: 1.1007 - mae: 0.8874 - rmse: 1.1007 - val_loss: 0.6424 - val_mae: 0.6144 - val_rmse: 0.6478
# Epoch 2/50
# 27/27 [==============================] - 1s 27ms/step - loss: 0.7655 - mae: 0.6111 - rmse: 0.7655 - val_loss: 0.6540 - val_mae: 0.6271 - val_rmse: 0.6584
# Epoch 3/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.6903 - mae: 0.5599 - rmse: 0.6903 - val_loss: 0.5449 - val_mae: 0.5111 - val_rmse: 0.5523
# Epoch 4/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.5792 - mae: 0.4690 - rmse: 0.5792 - val_loss: 0.4072 - val_mae: 0.3633 - val_rmse: 0.4157
# Epoch 5/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.4878 - mae: 0.3971 - rmse: 0.4878 - val_loss: 0.3143 - val_mae: 0.2620 - val_rmse: 0.3226
# Epoch 6/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.4240 - mae: 0.3387 - rmse: 0.4240 - val_loss: 0.3070 - val_mae: 0.2548 - val_rmse: 0.3158
# Epoch 7/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.4209 - mae: 0.3446 - rmse: 0.4209 - val_loss: 0.2540 - val_mae: 0.2087 - val_rmse: 0.2618
# Epoch 8/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3976 - mae: 0.3182 - rmse: 0.3976 - val_loss: 0.2677 - val_mae: 0.2200 - val_rmse: 0.2746
# Epoch 9/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.3864 - mae: 0.3102 - rmse: 0.3864 - val_loss: 0.2297 - val_mae: 0.1878 - val_rmse: 0.2396
# Epoch 10/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3783 - mae: 0.2992 - rmse: 0.3783 - val_loss: 0.2277 - val_mae: 0.1904 - val_rmse: 0.2366
# Epoch 11/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3269 - mae: 0.2712 - rmse: 0.3269 - val_loss: 0.2838 - val_mae: 0.2313 - val_rmse: 0.2934
# Epoch 12/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.3250 - mae: 0.2609 - rmse: 0.3250 - val_loss: 0.3066 - val_mae: 0.2514 - val_rmse: 0.3221
# Epoch 13/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.3224 - mae: 0.2577 - rmse: 0.3224 - val_loss: 0.2143 - val_mae: 0.1704 - val_rmse: 0.2270
# Epoch 14/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2955 - mae: 0.2435 - rmse: 0.2955 - val_loss: 0.2462 - val_mae: 0.2013 - val_rmse: 0.2545
# Epoch 15/50
# 27/27 [==============================] - 1s 27ms/step - loss: 0.3043 - mae: 0.2452 - rmse: 0.3043 - val_loss: 0.2064 - val_mae: 0.1688 - val_rmse: 0.2145
# Epoch 16/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2919 - mae: 0.2350 - rmse: 0.2919 - val_loss: 0.2498 - val_mae: 0.2047 - val_rmse: 0.2601
# Epoch 17/50
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2630 - mae: 0.2146 - rmse: 0.2630 - val_loss: 0.1971 - val_mae: 0.1618 - val_rmse: 0.2054
# Epoch 18/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2456 - mae: 0.1983 - rmse: 0.2456 - val_loss: 0.2158 - val_mae: 0.1699 - val_rmse: 0.2332
# Epoch 19/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2704 - mae: 0.2180 - rmse: 0.2704 - val_loss: 0.2125 - val_mae: 0.1636 - val_rmse: 0.2274
# Epoch 20/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2680 - mae: 0.2172 - rmse: 0.2680 - val_loss: 0.1945 - val_mae: 0.1550 - val_rmse: 0.2017
# Epoch 21/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2503 - mae: 0.2021 - rmse: 0.2503 - val_loss: 0.1993 - val_mae: 0.1599 - val_rmse: 0.2082
# Epoch 22/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2417 - mae: 0.1957 - rmse: 0.2417 - val_loss: 0.2989 - val_mae: 0.2568 - val_rmse: 0.2953
# Epoch 23/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2453 - mae: 0.1978 - rmse: 0.2453 - val_loss: 0.3563 - val_mae: 0.3133 - val_rmse: 0.3430
# Epoch 24/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2337 - mae: 0.1892 - rmse: 0.2337 - val_loss: 0.3006 - val_mae: 0.2548 - val_rmse: 0.2970
# Epoch 25/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2314 - mae: 0.1859 - rmse: 0.2314 - val_loss: 0.1982 - val_mae: 0.1608 - val_rmse: 0.2060
# Epoch 26/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2298 - mae: 0.1840 - rmse: 0.2298 - val_loss: 0.2215 - val_mae: 0.1805 - val_rmse: 0.2213
# Epoch 27/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2239 - mae: 0.1825 - rmse: 0.2239 - val_loss: 0.2294 - val_mae: 0.1931 - val_rmse: 0.2332
# Epoch 28/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2261 - mae: 0.1835 - rmse: 0.2261 - val_loss: 0.2100 - val_mae: 0.1755 - val_rmse: 0.2148
# Epoch 29/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2245 - mae: 0.1862 - rmse: 0.2245 - val_loss: 0.1881 - val_mae: 0.1544 - val_rmse: 0.1982
# Epoch 30/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2276 - mae: 0.1823 - rmse: 0.2276 - val_loss: 0.1907 - val_mae: 0.1622 - val_rmse: 0.1941
# Epoch 31/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2035 - mae: 0.1650 - rmse: 0.2035 - val_loss: 0.2108 - val_mae: 0.1707 - val_rmse: 0.2168
# Epoch 32/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2124 - mae: 0.1690 - rmse: 0.2124 - val_loss: 0.1911 - val_mae: 0.1549 - val_rmse: 0.1947
# Epoch 33/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2073 - mae: 0.1657 - rmse: 0.2073 - val_loss: 0.1902 - val_mae: 0.1528 - val_rmse: 0.1949
# Epoch 34/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2106 - mae: 0.1697 - rmse: 0.2106 - val_loss: 0.2440 - val_mae: 0.2030 - val_rmse: 0.2522
# Epoch 35/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2071 - mae: 0.1672 - rmse: 0.2071 - val_loss: 0.2480 - val_mae: 0.2088 - val_rmse: 0.2572
# Epoch 36/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2137 - mae: 0.1718 - rmse: 0.2137 - val_loss: 0.2145 - val_mae: 0.1795 - val_rmse: 0.2189
# Epoch 37/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2156 - mae: 0.1724 - rmse: 0.2156 - val_loss: 0.2248 - val_mae: 0.1831 - val_rmse: 0.2282
# Epoch 38/50
# 27/27 [==============================] - 1s 27ms/step - loss: 0.2085 - mae: 0.1704 - rmse: 0.2085 - val_loss: 0.1811 - val_mae: 0.1484 - val_rmse: 0.1868
# Epoch 39/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.2049 - mae: 0.1661 - rmse: 0.2049 - val_loss: 0.1866 - val_mae: 0.1538 - val_rmse: 0.1965
# Epoch 40/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2048 - mae: 0.1622 - rmse: 0.2048 - val_loss: 0.2029 - val_mae: 0.1669 - val_rmse: 0.2127
# Epoch 41/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2094 - mae: 0.1676 - rmse: 0.2094 - val_loss: 0.1974 - val_mae: 0.1644 - val_rmse: 0.2019
# Epoch 42/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.2056 - mae: 0.1688 - rmse: 0.2056 - val_loss: 0.2261 - val_mae: 0.1882 - val_rmse: 0.2358
# Epoch 43/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.1963 - mae: 0.1601 - rmse: 0.1963 - val_loss: 0.2262 - val_mae: 0.1868 - val_rmse: 0.2354
# Epoch 44/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.1996 - mae: 0.1602 - rmse: 0.1996 - val_loss: 0.2221 - val_mae: 0.1829 - val_rmse: 0.2307
# Epoch 45/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2007 - mae: 0.1643 - rmse: 0.2007 - val_loss: 0.2103 - val_mae: 0.1763 - val_rmse: 0.2130
# Epoch 46/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.1965 - mae: 0.1611 - rmse: 0.1965 - val_loss: 0.2112 - val_mae: 0.1764 - val_rmse: 0.2173
# Epoch 47/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.2017 - mae: 0.1608 - rmse: 0.2017 - val_loss: 0.1870 - val_mae: 0.1532 - val_rmse: 0.1939
# Epoch 48/50
# 27/27 [==============================] - 1s 25ms/step - loss: 0.1904 - mae: 0.1584 - rmse: 0.1904 - val_loss: 0.1907 - val_mae: 0.1608 - val_rmse: 0.1965
# Epoch 49/50
# 27/27 [==============================] - 1s 26ms/step - loss: 0.1861 - mae: 0.1529 - rmse: 0.1861 - val_loss: 0.1857 - val_mae: 0.1556 - val_rmse: 0.1907
# Epoch 50/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.1984 - mae: 0.1620 - rmse: 0.1984 - val_loss: 0.1911 - val_mae: 0.1622 - val_rmse: 0.1966

# %%
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 1s 9ms/step
# MAPA (Accuracy): 99.33%

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='W')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
