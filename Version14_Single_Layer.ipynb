# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
weekly_df = daily_df.resample('W', on='Order Date')['Total Profit'].sum().reset_index()
weekly_df.columns = ['Order Date', 'Total Profit']
weekly_df.set_index('Order Date', inplace=True)

# %%
Q1 = weekly_df['Total Profit'].quantile( 0.25)
Q3 = weekly_df['Total Profit'].quantile( 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
weekly_df = weekly_df[(weekly_df['Total Profit'] >= lower_bound) & 
                      (weekly_df['Total Profit'] <= upper_bound)]

# %%
train_data, test_data = train_test_split(weekly_df, test_size= 0.2, shuffle=False)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM(64, input_shape=(seq_length, 1))),
    Dense(1)
])

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 27/27 [==============================] - 5s 43ms/step - loss: 0.2824 - mae: 0.2442 - rmse: 0.2824 - val_loss: 0.1994 - val_mae: 0.1620 - val_rmse: 0.2092
# Epoch 2/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1895 - mae: 0.1553 - rmse: 0.1895 - val_loss: 0.1950 - val_mae: 0.1579 - val_rmse: 0.2044
# Epoch 3/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1903 - mae: 0.1546 - rmse: 0.1903 - val_loss: 0.1948 - val_mae: 0.1580 - val_rmse: 0.2043
# Epoch 4/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1860 - mae: 0.1514 - rmse: 0.1860 - val_loss: 0.1937 - val_mae: 0.1571 - val_rmse: 0.2030
# Epoch 5/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1868 - mae: 0.1512 - rmse: 0.1868 - val_loss: 0.1957 - val_mae: 0.1625 - val_rmse: 0.2034
# Epoch 6/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1900 - mae: 0.1537 - rmse: 0.1900 - val_loss: 0.1920 - val_mae: 0.1587 - val_rmse: 0.2001
# Epoch 7/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1883 - mae: 0.1537 - rmse: 0.1883 - val_loss: 0.1911 - val_mae: 0.1555 - val_rmse: 0.2001
# Epoch 8/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1853 - mae: 0.1502 - rmse: 0.1853 - val_loss: 0.1896 - val_mae: 0.1562 - val_rmse: 0.1979
# Epoch 9/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1850 - mae: 0.1504 - rmse: 0.1850 - val_loss: 0.1900 - val_mae: 0.1572 - val_rmse: 0.1980
# Epoch 10/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1852 - mae: 0.1499 - rmse: 0.1852 - val_loss: 0.1883 - val_mae: 0.1551 - val_rmse: 0.1966
# Epoch 11/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1851 - mae: 0.1495 - rmse: 0.1851 - val_loss: 0.1877 - val_mae: 0.1549 - val_rmse: 0.1959
# Epoch 12/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1846 - mae: 0.1496 - rmse: 0.1846 - val_loss: 0.1879 - val_mae: 0.1534 - val_rmse: 0.1966
# Epoch 13/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1831 - mae: 0.1503 - rmse: 0.1831 - val_loss: 0.1861 - val_mae: 0.1528 - val_rmse: 0.1945
# Epoch 14/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1816 - mae: 0.1482 - rmse: 0.1816 - val_loss: 0.1851 - val_mae: 0.1526 - val_rmse: 0.1932
# Epoch 15/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1798 - mae: 0.1473 - rmse: 0.1798 - val_loss: 0.1849 - val_mae: 0.1516 - val_rmse: 0.1932
# Epoch 16/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1821 - mae: 0.1473 - rmse: 0.1821 - val_loss: 0.1901 - val_mae: 0.1568 - val_rmse: 0.1987
# Epoch 17/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1872 - mae: 0.1520 - rmse: 0.1872 - val_loss: 0.1837 - val_mae: 0.1516 - val_rmse: 0.1918
# Epoch 18/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1811 - mae: 0.1468 - rmse: 0.1811 - val_loss: 0.1830 - val_mae: 0.1511 - val_rmse: 0.1910
# Epoch 19/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1806 - mae: 0.1471 - rmse: 0.1806 - val_loss: 0.1873 - val_mae: 0.1546 - val_rmse: 0.1956
# Epoch 20/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1839 - mae: 0.1505 - rmse: 0.1839 - val_loss: 0.1818 - val_mae: 0.1504 - val_rmse: 0.1895
# Epoch 21/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1810 - mae: 0.1476 - rmse: 0.1810 - val_loss: 0.1836 - val_mae: 0.1520 - val_rmse: 0.1907
# Epoch 22/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1812 - mae: 0.1473 - rmse: 0.1812 - val_loss: 0.1815 - val_mae: 0.1498 - val_rmse: 0.1893
# Epoch 23/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1798 - mae: 0.1461 - rmse: 0.1798 - val_loss: 0.1803 - val_mae: 0.1494 - val_rmse: 0.1877
# Epoch 24/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1790 - mae: 0.1456 - rmse: 0.1790 - val_loss: 0.1793 - val_mae: 0.1487 - val_rmse: 0.1866
# Epoch 25/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1795 - mae: 0.1454 - rmse: 0.1795 - val_loss: 0.1786 - val_mae: 0.1482 - val_rmse: 0.1860
# Epoch 26/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1775 - mae: 0.1445 - rmse: 0.1775 - val_loss: 0.1849 - val_mae: 0.1543 - val_rmse: 0.1926
# Epoch 27/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1790 - mae: 0.1451 - rmse: 0.1790 - val_loss: 0.1784 - val_mae: 0.1485 - val_rmse: 0.1858
# Epoch 28/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1778 - mae: 0.1443 - rmse: 0.1778 - val_loss: 0.1761 - val_mae: 0.1461 - val_rmse: 0.1825
# Epoch 29/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1773 - mae: 0.1449 - rmse: 0.1773 - val_loss: 0.1757 - val_mae: 0.1471 - val_rmse: 0.1826
# Epoch 30/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1768 - mae: 0.1445 - rmse: 0.1768 - val_loss: 0.1791 - val_mae: 0.1507 - val_rmse: 0.1859
# Epoch 31/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1764 - mae: 0.1434 - rmse: 0.1764 - val_loss: 0.1731 - val_mae: 0.1432 - val_rmse: 0.1783
# Epoch 32/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1752 - mae: 0.1412 - rmse: 0.1752 - val_loss: 0.1756 - val_mae: 0.1452 - val_rmse: 0.1799
# Epoch 33/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1763 - mae: 0.1455 - rmse: 0.1763 - val_loss: 0.1710 - val_mae: 0.1451 - val_rmse: 0.1766
# Epoch 34/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1738 - mae: 0.1411 - rmse: 0.1738 - val_loss: 0.1741 - val_mae: 0.1438 - val_rmse: 0.1768
# Epoch 35/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1754 - mae: 0.1420 - rmse: 0.1754 - val_loss: 0.1835 - val_mae: 0.1548 - val_rmse: 0.1886
# Epoch 36/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1780 - mae: 0.1439 - rmse: 0.1780 - val_loss: 0.1647 - val_mae: 0.1396 - val_rmse: 0.1685
# Epoch 37/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1717 - mae: 0.1397 - rmse: 0.1717 - val_loss: 0.1660 - val_mae: 0.1374 - val_rmse: 0.1686
# Epoch 38/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1727 - mae: 0.1397 - rmse: 0.1727 - val_loss: 0.1634 - val_mae: 0.1383 - val_rmse: 0.1667
# Epoch 39/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1732 - mae: 0.1402 - rmse: 0.1732 - val_loss: 0.1637 - val_mae: 0.1393 - val_rmse: 0.1675
# Epoch 40/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1703 - mae: 0.1377 - rmse: 0.1703 - val_loss: 0.1700 - val_mae: 0.1393 - val_rmse: 0.1722
# Epoch 41/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1714 - mae: 0.1381 - rmse: 0.1714 - val_loss: 0.1625 - val_mae: 0.1380 - val_rmse: 0.1651
# Epoch 42/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1702 - mae: 0.1389 - rmse: 0.1702 - val_loss: 0.1625 - val_mae: 0.1377 - val_rmse: 0.1654
# Epoch 43/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1716 - mae: 0.1382 - rmse: 0.1716 - val_loss: 0.1641 - val_mae: 0.1364 - val_rmse: 0.1662
# Epoch 44/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1715 - mae: 0.1385 - rmse: 0.1715 - val_loss: 0.1643 - val_mae: 0.1363 - val_rmse: 0.1661
# Epoch 45/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1682 - mae: 0.1372 - rmse: 0.1682 - val_loss: 0.1624 - val_mae: 0.1384 - val_rmse: 0.1653
# Epoch 46/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1689 - mae: 0.1376 - rmse: 0.1689 - val_loss: 0.1619 - val_mae: 0.1374 - val_rmse: 0.1644
# Epoch 47/50
# 27/27 [==============================] - 0s 8ms/step - loss: 0.1703 - mae: 0.1378 - rmse: 0.1703 - val_loss: 0.1623 - val_mae: 0.1383 - val_rmse: 0.1652
# Epoch 48/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1690 - mae: 0.1366 - rmse: 0.1690 - val_loss: 0.1628 - val_mae: 0.1393 - val_rmse: 0.1664
# Epoch 49/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1698 - mae: 0.1392 - rmse: 0.1698 - val_loss: 0.1621 - val_mae: 0.1381 - val_rmse: 0.1646
# Epoch 50/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1703 - mae: 0.1393 - rmse: 0.1703 - val_loss: 0.1635 - val_mae: 0.1402 - val_rmse: 0.1668

# %%
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 1s 4ms/step
# MAPA (Accuracy): 99.42%

# %%
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")
# Out:
# MAPA (Accuracy): 53.78%

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='W')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
