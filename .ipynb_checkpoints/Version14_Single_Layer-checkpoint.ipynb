# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
weekly_df = daily_df.resample('W', on='Order Date')['Total Profit'].sum().reset_index()
weekly_df.columns = ['Order Date', 'Total Profit']
weekly_df.set_index('Order Date', inplace=True)

# %%
Q1 = weekly_df['Total Profit'].quantile( 0.25)
Q3 = weekly_df['Total Profit'].quantile( 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
weekly_df = weekly_df[(weekly_df['Total Profit'] >= lower_bound) & 
                      (weekly_df['Total Profit'] <= upper_bound)]

# %%
train_data, test_data = train_test_split(weekly_df, test_size= 0.2, shuffle=False)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM(64, input_shape=(seq_length, 1))),
    Dense(1)
])

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 27/27 [==============================] - 6s 48ms/step - loss: 0.2647 - mae: 0.2252 - rmse: 0.2647 - val_loss: 0.2165 - val_mae: 0.1767 - val_rmse: 0.2266
# Epoch 2/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1974 - mae: 0.1599 - rmse: 0.1974 - val_loss: 0.1975 - val_mae: 0.1605 - val_rmse: 0.2072
# Epoch 3/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1909 - mae: 0.1556 - rmse: 0.1909 - val_loss: 0.1942 - val_mae: 0.1579 - val_rmse: 0.2035
# Epoch 4/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1907 - mae: 0.1539 - rmse: 0.1907 - val_loss: 0.1929 - val_mae: 0.1579 - val_rmse: 0.2019
# Epoch 5/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1930 - mae: 0.1561 - rmse: 0.1930 - val_loss: 0.1924 - val_mae: 0.1583 - val_rmse: 0.2011
# Epoch 6/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1921 - mae: 0.1566 - rmse: 0.1921 - val_loss: 0.1917 - val_mae: 0.1569 - val_rmse: 0.2007
# Epoch 7/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1896 - mae: 0.1528 - rmse: 0.1896 - val_loss: 0.1924 - val_mae: 0.1592 - val_rmse: 0.2006
# Epoch 8/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1891 - mae: 0.1555 - rmse: 0.1891 - val_loss: 0.1904 - val_mae: 0.1563 - val_rmse: 0.1991
# Epoch 9/50
# 27/27 [==============================] - 0s 11ms/step - loss: 0.1904 - mae: 0.1551 - rmse: 0.1904 - val_loss: 0.1900 - val_mae: 0.1555 - val_rmse: 0.1989
# Epoch 10/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1887 - mae: 0.1529 - rmse: 0.1887 - val_loss: 0.1893 - val_mae: 0.1553 - val_rmse: 0.1980
# Epoch 11/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1847 - mae: 0.1495 - rmse: 0.1847 - val_loss: 0.1887 - val_mae: 0.1549 - val_rmse: 0.1973
# Epoch 12/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1871 - mae: 0.1513 - rmse: 0.1871 - val_loss: 0.1887 - val_mae: 0.1561 - val_rmse: 0.1969
# Epoch 13/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.
50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1807 - mae: 0.1468 - rmse: 0.1807 - val_loss: 0.1780 - val_mae: 0.1479 - val_rmse: 0.1852
# Epoch 37/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1815 - mae: 0.1471 - rmse: 0.1815 - val_loss: 0.1814 - val_mae: 0.1510 - val_rmse: 0.1890
# Epoch 38/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1816 - mae: 0.1463 - rmse: 0.1816 - val_loss: 0.1894 - val_mae: 0.1565 - val_rmse: 0.1951
# Epoch 39/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1802 - mae: 0.1448 - rmse: 0.1802 - val_loss: 0.1776 - val_mae: 0.1478 - val_rmse: 0.1845
# Epoch 40/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1765 - mae: 0.1430 - rmse: 0.1765 - val_loss: 0.1787 - val_mae: 0.1491 - val_rmse: 0.1861
# Epoch 41/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1795 - mae: 0.1472 - rmse: 0.1795 - val_loss: 0.1756 - val_mae: 0.1466 - val_rmse: 0.1825
# Epoch 42/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1819 - mae: 0.1485 - rmse: 0.1819 - val_loss: 0.1832 - val_mae: 0.1536 - val_rmse: 0.1906
# Epoch 43/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1798 - mae: 0.1462 - rmse: 0.1798 - val_loss: 0.1763 - val_mae: 0.1476 - val_rmse: 0.1833
# Epoch 44/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1781 - mae: 0.1450 - rmse: 0.1781 - val_loss: 0.1739 - val_mae: 0.1458 - val_rmse: 0.1806
# Epoch 45/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1791 - mae: 0.1438 - rmse: 0.1791 - val_loss: 0.1732 - val_mae: 0.1443 - val_rmse: 0.1794
# Epoch 46/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1772 - mae: 0.1415 - rmse: 0.1772 - val_loss: 0.1807 - val_mae: 0.1494 - val_rmse: 0.1858
# Epoch 47/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1777 - mae: 0.1447 - rmse: 0.1777 - val_loss: 0.1707 - val_mae: 0.1431 - val_rmse: 0.1766
# Epoch 48/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1750 - mae: 0.1438 - rmse: 0.1750 - val_loss: 0.1734 - val_mae: 0.1471 - val_rmse: 0.1796
# Epoch 49/50
# 27/27 [==============================] - 0s 10ms/step - loss: 0.1765 - mae: 0.1434 - rmse: 0.1765 - val_loss: 0.1687 - val_mae: 0.1410 - val_rmse: 0.1739
# Epoch 50/50
# 27/27 [==============================] - 0s 9ms/step - loss: 0.1725 - mae: 0.1396 - rmse: 0.1725 - val_loss: 0.1667 - val_mae: 0.1406 - val_rmse: 0.1716

# %%
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 7ms/step
# MAPA (Accuracy): 99.41%

# %%
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")
# Out:
# MAPA (Accuracy): 50.16%

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='W')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
