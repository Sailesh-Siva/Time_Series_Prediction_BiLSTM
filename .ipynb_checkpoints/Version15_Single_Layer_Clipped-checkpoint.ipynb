# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
monthly_df = daily_df.resample('ME', on='Order Date')['Total Profit'].sum().reset_index()
monthly_df.columns = ['Order Date', 'Total Profit']
monthly_df.set_index('Order Date', inplace=True)

# %%
monthly_df
# Out:
#             Total Profit
# Order Date
# 2014-01-31  1.556656e+10
# 2014-02-28  1.402973e+10
# 2014-03-31  1.556248e+10
# 2014-04-30  1.510544e+10
# 2014-05-31  1.559264e+10
# ...                  ...
# 2024-05-31  1.558589e+10
# 2024-06-30  1.506300e+10
# 2024-07-31  1.553073e+10
# 2024-08-31  1.558169e+10
# 2024-09-30  5.059861e+09
#
# [129 rows x 1 columns]

# %%
monthly_df['Total Profit'] = monthly_df['Total Profit']/10**10

# %%
monthly_df
# Out:
#             Total Profit
# Order Date
# 2014-01-31      1.556656
# 2014-02-28      1.402973
# 2014-03-31      1.556248
# 2014-04-30      1.510544
# 2014-05-31      1.559264
# ...                  ...
# 2024-05-31      1.558589
# 2024-06-30      1.506300
# 2024-07-31      1.553073
# 2024-08-31      1.558169
# 2024-09-30      0.505986
#
# [129 rows x 1 columns]

# %%
sns.boxplot(monthly_df)
# Out:
# <Axes: >

# %%
Q1 = monthly_df['Total Profit'].quantile(0.25)
Q3 = monthly_df['Total Profit'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
monthly_df = monthly_df[(monthly_df['Total Profit'] >= lower_bound) & 
                      (monthly_df['Total Profit'] <= upper_bound)]

# %%
sns.boxplot(monthly_df)
# Out:
# <Axes: >

# %%
train_data, test_data = train_test_split(monthly_df, test_size= 0.2, shuffle=False)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
train_scaled
# Out:
# array([[0.87638014],
#        [0.87273679],
#        [0.46494252],
#        [0.89964861],
#        [0.42641841],
#        [0.8807608 ],
#        [0.8668039 ],
#        [0.46434173],
#        [0.90221967],
#        [0.40806572],
#        [0.92247193],
#        [0.98900127],
#        [0.89434053],
#        [0.43766566],
#        [0.8225371 ],
#        [0.48824541],
#        [0.86426116],
#        [0.89511126],
#        [0.51743866],
#        [0.87828209],
#        [0.45746252],
#        [0.922182  ],
#        [0.88653958],
#        [0.0690686 ],
#        [0.88785146],
#        [0.40681191],
#        [0.87997365],
#        [0.40239891],
#        [0.94090423],
#        [0.87327799],
#        [0.36491614],
#        [0.88634366],
#        [0.50145826],
#        [0.87992954],
#        [0.88729827],
#        [0.92594218],
#        [0.39105671],
#        [0.92407528],
#        [0.44818019],
#        [0.93258058],
#        [0.84697928],
#        [0.43334755],
#        [0.90060935],
#        [0.43024151],
#        [0.86396627],
#        [0.9038795 ],
#        [0.8503903 ],
#        [0.41045283],
#        [0.93362507],
#        [0.51555386],
#        [0.87720908],
#        [0.89876702],
#        [0.47607659],
#        [0.95220992],
#        [0.38488945],
#        [0.88091441],
#        [0.86375941],
#        [0.90398282],
#        [0.47639578],
#        [1.        ],
#        [0.45383348],
#        [0.89905997],
#        [0.91091088],
#        [0.37855325],
#        [0.85500368],
#        [0.47852138],
#        [0.95952899],
#        [0.85997231],
#        [0.        ],
#        [0.87271757],
#        [0.46498561],
#        [0.8722159 ],
#        [0.36546246],
#        [0.97881688],
#        [0.86625803],
#        [0.40624539],
#        [0.90791301],
#        [0.37041863],
#        [0.9003835 ],
#        [0.80957656],
#        [0.86995739],
#        [0.39709874],
#        [0.93498401],
#        [0.48337721],
#        [0.88732922],
#        [0.78109555],
#        [0.48703441],
#        [0.88027888],
#        [0.42835293],
#        [0.85209293],
#        [0.87689001],
#        [0.88455273],
#        [0.44896745],
#        [0.95535302],
#        [0.42853404],
#        [0.88771887]])

# %%
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM(64, input_shape=(seq_length, 1))),
    Dense(1)
])

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 6/6 [==============================] - 13s 249ms/step - loss: 0.5989 - mae: 0.5532 - rmse: 0.5566 - val_loss: 0.3735 - val_mae: 0.3126 - val_rmse: 0.3735
# Epoch 2/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2820 - mae: 0.2423 - rmse: 0.2842 - val_loss: 0.3917 - val_mae: 0.2509 - val_rmse: 0.3917
# Epoch 3/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2841 - mae: 0.2017 - rmse: 0.3058 - val_loss: 0.3270 - val_mae: 0.2689 - val_rmse: 0.3270
# Epoch 4/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2554 - mae: 0.2388 - rmse: 0.2560 - val_loss: 0.3203 - val_mae: 0.2892 - val_rmse: 0.3203
# Epoch 5/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2615 - mae: 0.2494 - rmse: 0.2579 - val_loss: 0.3164 - val_mae: 0.2781 - val_rmse: 0.3164
# Epoch 6/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2491 - mae: 0.2280 - rmse: 0.2461 - val_loss: 0.3350 - val_mae: 0.2631 - val_rmse: 0.3350
# Epoch 7/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2537 - mae: 0.2121 - rmse: 0.2612 - val_loss: 0.3249 - val_mae: 0.2679 - val_rmse: 0.3249
# Epoch 8/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2472 - mae: 0.2324 - rmse: 0.2455 - val_loss: 0.3147 - val_mae: 0.2803 - val_rmse: 0.3147
# Epoch 9/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2491 - mae: 0.2391 - rmse: 0.2444 - val_loss: 0.3150 - val_mae: 0.2759 - val_rmse: 0.3150
# Epoch 10/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2453 - mae: 0.2287 - rmse: 0.2398 - val_loss: 0.3222 - val_mae: 0.2674 - val_rmse: 0.3222
# Epoch 11/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2497 - mae: 0.2181 - rmse: 0.2493 - val_loss: 0.3242 - val_mae: 0.2652 - val_rmse: 0.3242
# Epoch 12/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2437 - mae: 0.2263 - rmse: 0.2427 - val_loss: 0.3128 - val_mae: 0.2764 - val_rmse: 0.3128
# Epoch 13/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.2471 - mae: 0.2367 - rmse: 0.2429 - val_loss: 0.3124 - val_mae: 0.2750 - val_rmse: 0.3124
# Epoch 14/50
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2456 - mae: 0.2340 - rmse: 0.2462 - val_loss: 0.3133 - val_mae: 0.2711 - val_rmse: 0.3133
# Epoch 15/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2436 - mae: 0.2303 - rmse: 0.2420 - val_loss: 0.3128 - val_mae: 0.2700 - val_rmse: 0.3128
# Epoch 16/50
# 6/6 [==============================] - 0s 21ms/step - loss: 0.
50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2194 - mae: 0.1956 - rmse: 0.2145 - val_loss: 0.2747 - val_mae: 0.2177 - val_rmse: 0.2747
# Epoch 38/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2089 - mae: 0.1845 - rmse: 0.2054 - val_loss: 0.2760 - val_mae: 0.2159 - val_rmse: 0.2760
# Epoch 39/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2071 - mae: 0.1842 - rmse: 0.2006 - val_loss: 0.2722 - val_mae: 0.2131 - val_rmse: 0.2722
# Epoch 40/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2061 - mae: 0.1792 - rmse: 0.2094 - val_loss: 0.2742 - val_mae: 0.2103 - val_rmse: 0.2742
# Epoch 41/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2050 - mae: 0.1773 - rmse: 0.1914 - val_loss: 0.2860 - val_mae: 0.2082 - val_rmse: 0.2860
# Epoch 42/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2096 - mae: 0.1793 - rmse: 0.2022 - val_loss: 0.2944 - val_mae: 0.2098 - val_rmse: 0.2944
# Epoch 43/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2131 - mae: 0.1815 - rmse: 0.2318 - val_loss: 0.2704 - val_mae: 0.2062 - val_rmse: 0.2704
# Epoch 44/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2001 - mae: 0.1713 - rmse: 0.1956 - val_loss: 0.2770 - val_mae: 0.2060 - val_rmse: 0.2770
# Epoch 45/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2014 - mae: 0.1704 - rmse: 0.2014 - val_loss: 0.2715 - val_mae: 0.2057 - val_rmse: 0.2715
# Epoch 46/50
# 6/6 [==============================] - 0s 18ms/step - loss: 0.2048 - mae: 0.1748 - rmse: 0.2004 - val_loss: 0.2877 - val_mae: 0.2064 - val_rmse: 0.2877
# Epoch 47/50
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2090 - mae: 0.1682 - rmse: 0.2055 - val_loss: 0.2663 - val_mae: 0.2051 - val_rmse: 0.2663
# Epoch 48/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2075 - mae: 0.1792 - rmse: 0.2037 - val_loss: 0.2766 - val_mae: 0.2054 - val_rmse: 0.2766
# Epoch 49/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2041 - mae: 0.1698 - rmse: 0.2001 - val_loss: 0.2766 - val_mae: 0.2050 - val_rmse: 0.2766
# Epoch 50/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.1995 - mae: 0.1682 - rmse: 0.2165 - val_loss: 0.2678 - val_mae: 0.2043 - val_rmse: 0.2678

# %%
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 890ms/step
# MAPA (Accuracy): 98.48%

# %%
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")
# Out:
# MAPA (Accuracy): 4.22%

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='ME')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
percentage_error = np.abs((y_test_inv - y_pred_inv) / y_test_inv) * 100

plt.figure(figsize=(12, 6))
plt.plot(test_dates, percentage_error, color='purple', label='Percentage Error')
plt.title('Percentage Error Over Time')
plt.xlabel('Date')
plt.ylabel('Percentage Error (%)')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
