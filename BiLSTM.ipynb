# %% [markdown]
# <h1>BiLSTM</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.callbacks import EarlyStopping

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']]
df['Order Date'] = pd.to_datetime(df['Order Date'])

df.set_index('Order Date', inplace=True)

monthly_df = df['Total Profit'].resample('ME').sum().to_frame()

print("Index frequency:", monthly_df.index.freq)
# Out:
# Index frequency: <MonthEnd>

# %%
monthly_df
# Out:
#             Total Profit
# Order Date
# 2014-01-31  1.556656e+10
# 2014-02-28  1.402973e+10
# 2014-03-31  1.556248e+10
# 2014-04-30  1.510544e+10
# 2014-05-31  1.559264e+10
# ...                  ...
# 2024-05-31  1.558589e+10
# 2024-06-30  1.506300e+10
# 2024-07-31  1.553073e+10
# 2024-08-31  1.558169e+10
# 2024-09-30  5.059861e+09
#
# [129 rows x 1 columns]

# %%
train_data, test_data = train_test_split(monthly_df, test_size= 0.2, shuffle=False)

# %%
train_data
# Out:
#             Total Profit
# Order Date
# 2014-01-31  1.556656e+10
# 2014-02-28  1.402973e+10
# 2014-03-31  1.556248e+10
# 2014-04-30  1.510544e+10
# 2014-05-31  1.559264e+10
# ...                  ...
# 2022-03-31  1.557572e+10
# 2022-04-30  1.508754e+10
# 2022-05-31  1.565507e+10
# 2022-06-30  1.506464e+10
# 2022-07-31  1.557927e+10
#
# [103 rows x 1 columns]

# %%
test_data
# Out:
#             Total Profit
# Order Date
# 2022-08-31  1.561939e+10
# 2022-09-30  1.507442e+10
# 2022-10-31  1.561683e+10
# 2022-11-30  1.509961e+10
# 2022-12-31  1.562022e+10
# 2023-01-31  1.559258e+10
# 2023-02-28  1.407188e+10
# 2023-03-31  1.555777e+10
# 2023-04-30  1.512009e+10
# 2023-05-31  1.554336e+10
# 2023-06-30  1.505409e+10
# 2023-07-31  1.565103e+10
# 2023-08-31  1.555782e+10
# 2023-09-30  1.506215e+10
# 2023-10-31  1.559817e+10
# 2023-11-30  1.506337e+10
# 2023-12-31  1.562711e+10
# 2024-01-31  1.558438e+10
# 2024-02-29  1.449321e+10
# 2024-03-31  1.557054e+10
# 2024-04-30  1.504912e+10
# 2024-05-31  1.558589e+10
# 2024-06-30  1.506300e+10
# 2024-07-31  1.553073e+10
# 2024-08-31  1.558169e+10
# 2024-09-30  5.059861e+09

# %%
test_data = test_data[:-1].copy()

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
#Creating Sequences for BiLSTM
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM(64, input_shape=(seq_length, 1))),
    Dense(1)
])

# %%
model.compile(optimizer='adam', loss='mae', metrics='mae')

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 100, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 5s 125ms/step - loss: 0.6143 - mae: 0.6143 - val_loss: 0.3317 - val_mae: 0.3317
# Epoch 2/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.2427 - mae: 0.2427 - val_loss: 0.2076 - val_mae: 0.2076
# Epoch 3/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2054 - mae: 0.2054 - val_loss: 0.1608 - val_mae: 0.1608
# Epoch 4/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1893 - mae: 0.1893 - val_loss: 0.1745 - val_mae: 0.1745
# Epoch 5/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1900 - mae: 0.1900 - val_loss: 0.1661 - val_mae: 0.1661
# Epoch 6/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1826 - mae: 0.1826 - val_loss: 0.1473 - val_mae: 0.1473
# Epoch 7/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1717 - mae: 0.1717 - val_loss: 0.1466 - val_mae: 0.1466
# Epoch 8/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1713 - mae: 0.1713 - val_loss: 0.1471 - val_mae: 0.1471
# Epoch 9/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1708 - mae: 0.1708 - val_loss: 0.1456 - val_mae: 0.1456
# Epoch 10/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1713 - mae: 0.1713 - val_loss: 0.1450 - val_mae: 0.1450
# Epoch 11/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1692 - mae: 0.1692 - val_loss: 0.1449 - val_mae: 0.1449
# Epoch 12/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1691 - mae: 0.1691 - val_loss: 0.1451 - val_mae: 0.1451
# Epoch 13/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1725 - mae: 0.1725 - val_loss: 0.1440 - val_mae: 0.1440
# Epoch 14/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1681 - mae: 0.1681 - val_loss: 0.1438 - val_mae: 0.1438
# Epoch 15/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1669 - mae: 0.1669 - val_loss: 0.1432 - val_mae: 0.1432
# Epoch 16/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1687 - mae: 0.1687 - val_loss: 0.1426 - val_mae: 0.1426
# Epoch 17/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1741 - mae: 0.1741 - val_loss: 0.1565 - val_mae: 0.1565
# Epoch 18/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1712 - mae: 0.1712 - val_loss: 0.1432 - val_mae: 0.1432
# Epoch 19/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1747 - mae: 0.1747 - val_loss: 0.1447 - val_mae: 0.1447
# Epoch 20/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1663 - mae: 0.1663 - val_loss: 0.1413 - val_mae: 0.1413
# Epoch 21/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1668 - mae: 0.1668 - val_loss: 0.1417 - val_mae: 0.1417
# Epoch 22/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1694 - mae: 0.1694 - val_loss: 0.1477 - val_mae: 0.1477
# Epoch 23/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1646 - mae: 0.1646 - val_loss: 0.1411 - val_mae: 0.1411
# Epoch 24/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1623 - mae: 0.1623 - val_loss: 0.1398 - val_mae: 0.1398
# Epoch 25/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1643 - mae: 0.1643 - val_loss: 0.1385 - val_mae: 0.1385
# Epoch 26/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1627 - mae: 0.1627 - val_loss: 0.1414 - val_mae: 0.1414
# Epoch 27/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1602 - mae: 0.1602 - val_loss: 0.1422 - val_mae: 0.1422
# Epoch 28/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1617 - mae: 0.1617 - val_loss: 0.1378 - val_mae: 0.1378
# Epoch 29/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1667 - mae: 0.1667 - val_loss: 0.1366 - val_mae: 0.1366
# Epoch 30/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1614 - mae: 0.1614 - val_loss: 0.1427 - val_mae: 0.1427
# Epoch 31/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1594 - mae: 0.1594 - val_loss: 0.1372 - val_mae: 0.1372
# Epoch 32/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1565 - mae: 0.1565 - val_loss: 0.1387 - val_mae: 0.1387
# Epoch 33/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1634 - mae: 0.1634 - val_loss: 0.1392 - val_mae: 0.1392
# Epoch 34/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1588 - mae: 0.1588 - val_loss: 0.1351 - val_mae: 0.1351
# Epoch 35/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1614 - mae: 0.1614 - val_loss: 0.1398 - val_mae: 0.1398
# Epoch 36/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1556 - mae: 0.1556 - val_loss: 0.1323 - val_mae: 0.1323
# Epoch 37/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1607 - mae: 0.1607 - val_loss: 0.1340 - val_mae: 0.1340
# Epoch 38/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1600 - mae: 0.1600 - val_loss: 0.1506 - val_mae: 0.1506
# Epoch 39/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1602 - mae: 0.1602 - val_loss: 0.1272 - val_mae: 0.1272
# Epoch 40/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1520 - mae: 0.1520 - val_loss: 0.1256 - val_mae: 0.1256
# Epoch 41/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1538 - mae: 0.1538 - val_loss: 0.1418 - val_mae: 0.1418
# Epoch 42/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1535 - mae: 0.1535 - val_loss: 0.1257 - val_mae: 0.1257
# Epoch 43/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1366 - mae: 0.1366 - val_loss: 0.1284 - val_mae: 0.1284
# Epoch 44/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1431 - mae: 0.1431 - val_loss: 0.1243 - val_mae: 0.1243
# Epoch 45/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1358 - mae: 0.1358 - val_loss: 0.1095 - val_mae: 0.1095
# Epoch 46/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1260 - mae: 0.1260 - val_loss: 0.1022 - val_mae: 0.1022
# Epoch 47/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1195 - mae: 0.1195 - val_loss: 0.0974 - val_mae: 0.0974
# Epoch 48/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.1310 - mae: 0.1310 - val_loss: 0.0890 - val_mae: 0.0890
# Epoch 49/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1087 - mae: 0.1087 - val_loss: 0.0855 - val_mae: 0.0855
# Epoch 50/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1042 - mae: 0.1042 - val_loss: 0.0782 - val_mae: 0.0782
# Epoch 51/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.1077 - mae: 0.1077 - val_loss: 0.0836 - val_mae: 0.0836
# Epoch 52/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0970 - mae: 0.0970 - val_loss: 0.0678 - val_mae: 0.0678
# Epoch 53/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0859 - mae: 0.0859 - val_loss: 0.0637 - val_mae: 0.0637
# Epoch 54/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0812 - mae: 0.0812 - val_loss: 0.0600 - val_mae: 0.0600
# Epoch 55/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0813 - mae: 0.0813 - val_loss: 0.0540 - val_mae: 0.0540
# Epoch 56/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0773 - mae: 0.0773 - val_loss: 0.0481 - val_mae: 0.0481
# Epoch 57/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0797 - mae: 0.0797 - val_loss: 0.0452 - val_mae: 0.0452
# Epoch 58/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0786 - mae: 0.0786 - val_loss: 0.0416 - val_mae: 0.0416
# Epoch 59/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.
100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0494 - mae: 0.0494 - val_loss: 0.0248 - val_mae: 0.0248
# Epoch 96/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0474 - mae: 0.0474 - val_loss: 0.0254 - val_mae: 0.0254
# Epoch 97/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0476 - mae: 0.0476 - val_loss: 0.0251 - val_mae: 0.0251
# Epoch 98/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0483 - mae: 0.0483 - val_loss: 0.0392 - val_mae: 0.0392
# Epoch 99/100
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0515 - mae: 0.0515 - val_loss: 0.0261 - val_mae: 0.0261
# Epoch 100/100
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0464 - mae: 0.0464 - val_loss: 0.0278 - val_mae: 0.0278

# %%
model.save("bilstm_model.keras")

# %%
y_pred = model.predict(X_test)
train_pred = model.predict(X_train)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

y_train_inv = scaler.inverse_transform(y_train.reshape(-1, 1))
y_train_pred_inv = scaler.inverse_transform(train_pred)

mse = mean_squared_error(y_test_inv, y_pred_inv)
rmse = np.sqrt(mse)
mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
accuracy = 100 - mape

y_true = y_test_inv.flatten()
y_pred = y_pred_inv.flatten()

min_vals = np.minimum(np.abs(y_true), np.abs(y_pred))
minmax_errors = np.abs(y_true - y_pred) / min_vals
minmax_error = np.mean(minmax_errors)

mpe = np.mean((y_true - y_pred) / y_true) * 100

correlation = np.corrcoef(y_true, y_pred)[0, 1]

print(f"MAPE: {mape:.2f}%")
print(f"MAPA (Accuracy): {accuracy:.2f}%")
print(f"RMSE: {rmse:.2f}")
print(f"MinMax Error: {minmax_error:.4f}")
print(f"MPE: {mpe:.2f}%")
print(f"Correlation: {correlation:.4f}")

plt.figure(figsize=(16, 8))

plt.plot(train_dates, y_train_inv, label='Train Actual', color='blue', linewidth=2)
plt.plot(train_dates, y_train_pred_inv, label='Train Predicted', color='green', linestyle='--')

plt.plot(test_dates, y_test_inv, label='Test Actual', color='black', linewidth=2)
plt.plot(test_dates, y_pred_inv, label='Test Forecast', color='red', linestyle='--')


plt.title('Total Profit Forecasting (Train/Test)', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 3/3 [==============================] - 0s 5ms/step
# MAPE: 0.32%
# MAPA (Accuracy): 99.68%
# RMSE: 71818647.60
# MinMax Error: 0.0033
# MPE: 0.21%
# Correlation: 0.9867

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='ME')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
