# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
monthly_df = daily_df.resample('ME', on='Order Date')['Total Profit'].sum().reset_index()
monthly_df.columns = ['Order Date', 'Total Profit']
monthly_df.set_index('Order Date', inplace=True)

# %%
Q1 = monthly_df['Total Profit'].quantile(0.25)
Q3 = monthly_df['Total Profit'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
monthly_df = monthly_df[(monthly_df['Total Profit'] >= lower_bound) & 
                      (monthly_df['Total Profit'] <= upper_bound)]

# %%
train_data, test_data = train_test_split(monthly_df, test_size= 0.2, shuffle=False)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
train_scaled
# Out:
# array([[0.87638014],
#        [0.87273679],
#        [0.46494252],
#        [0.89964861],
#        [0.42641841],
#        [0.8807608 ],
#        [0.8668039 ],
#        [0.46434173],
#        [0.90221967],
#        [0.40806572],
#        [0.92247193],
#        [0.98900127],
#        [0.89434053],
#        [0.43766566],
#        [0.8225371 ],
#        [0.48824541],
#        [0.86426116],
#        [0.89511126],
#        [0.51743866],
#        [0.87828209],
#        [0.45746252],
#        [0.922182  ],
#        [0.88653958],
#        [0.0690686 ],
#        [0.88785146],
#        [0.40681191],
#        [0.87997365],
#        [0.40239891],
#        [0.94090423],
#        [0.87327799],
#        [0.36491614],
#        [0.88634366],
#        [0.50145826],
#        [0.87992954],
#        [0.88729827],
#        [0.92594218],
#        [0.39105671],
#        [0.92407528],
#        [0.44818019],
#        [0.93258058],
#        [0.84697928],
#        [0.43334755],
#        [0.90060935],
#        [0.43024151],
#        [0.86396627],
#        [0.9038795 ],
#        [0.8503903 ],
#        [0.41045283],
#        [0.93362507],
#        [0.51555386],
#        [0.87720908],
#        [0.89876702],
#        [0.47607659],
#        [0.95220992],
#        [0.38488945],
#        [0.88091441],
#        [0.86375941],
#        [0.90398282],
#        [0.47639578],
#        [1.        ],
#        [0.45383348],
#        [0.89905997],
#        [0.91091088],
#        [0.37855325],
#        [0.85500368],
#        [0.47852138],
#        [0.95952899],
#        [0.85997231],
#        [0.        ],
#        [0.87271757],
#        [0.46498561],
#        [0.8722159 ],
#        [0.36546246],
#        [0.97881688],
#        [0.86625803],
#        [0.40624539],
#        [0.90791301],
#        [0.37041863],
#        [0.9003835 ],
#        [0.80957656],
#        [0.86995739],
#        [0.39709874],
#        [0.93498401],
#        [0.48337721],
#        [0.88732922],
#        [0.78109555],
#        [0.48703441],
#        [0.88027888],
#        [0.42835293],
#        [0.85209293],
#        [0.87689001],
#        [0.88455273],
#        [0.44896745],
#        [0.95535302],
#        [0.42853404],
#        [0.88771887]])

# %%
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM(64, input_shape=(seq_length, 1))),
    Dense(1)
])

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 6/6 [==============================] - 9s 133ms/step - loss: 0.5909 - mae: 0.5453 - rmse: 0.5760 - val_loss: 0.3511 - val_mae: 0.3071 - val_rmse: 0.3511
# Epoch 2/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2648 - mae: 0.2147 - rmse: 0.2756 - val_loss: 0.4107 - val_mae: 0.2657 - val_rmse: 0.4107
# Epoch 3/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2983 - mae: 0.2134 - rmse: 0.2774 - val_loss: 0.3277 - val_mae: 0.2703 - val_rmse: 0.3277
# Epoch 4/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2491 - mae: 0.2324 - rmse: 0.2471 - val_loss: 0.3170 - val_mae: 0.2818 - val_rmse: 0.3170
# Epoch 5/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2480 - mae: 0.2366 - rmse: 0.2452 - val_loss: 0.3192 - val_mae: 0.2758 - val_rmse: 0.3192
# Epoch 6/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2456 - mae: 0.2274 - rmse: 0.2379 - val_loss: 0.3225 - val_mae: 0.2718 - val_rmse: 0.3225
# Epoch 7/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2455 - mae: 0.2228 - rmse: 0.2670 - val_loss: 0.3231 - val_mae: 0.2706 - val_rmse: 0.3231
# Epoch 8/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2419 - mae: 0.2258 - rmse: 0.2385 - val_loss: 0.3170 - val_mae: 0.2756 - val_rmse: 0.3170
# Epoch 9/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2442 - mae: 0.2324 - rmse: 0.2639 - val_loss: 0.3176 - val_mae: 0.2736 - val_rmse: 0.3176
# Epoch 10/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2435 - mae: 0.2264 - rmse: 0.2339 - val_loss: 0.3197 - val_mae: 0.2704 - val_rmse: 0.3197
# Epoch 11/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2423 - mae: 0.2218 - rmse: 0.2313 - val_loss: 0.3241 - val_mae: 0.2663 - val_rmse: 0.3241
# Epoch 12/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2437 - mae: 0.2164 - rmse: 0.2325 - val_loss: 0.3277 - val_mae: 0.2631 - val_rmse: 0.3277
# Epoch 13/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2469 - mae: 0.2120 - rmse: 0.2429 - val_loss: 0.3229 - val_mae: 0.2647 - val_rmse: 0.3229
# Epoch 14/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2396 - mae: 0.2185 - rmse: 0.2411 - val_loss: 0.3131 - val_mae: 0.2719 - val_rmse: 0.3131
# Epoch 15/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2432 - mae: 0.2331 - rmse: 0.2396 - val_loss: 0.3123 - val_mae: 0.2714 - val_rmse: 0.3123
# Epoch 16/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2445 - mae: 0.2185 - rmse: 0.2424 - val_loss: 0.3305 - val_mae: 0.2575 - val_rmse: 0.3305
# Epoch 17/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2476 - mae: 0.2110 - rmse: 0.2428 - val_loss: 0.3162 - val_mae: 0.2647 - val_rmse: 0.3162
# Epoch 18/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2396 - mae: 0.2182 - rmse: 0.2342 - val_loss: 0.3161 - val_mae: 0.2633 - val_rmse: 0.3161
# Epoch 19/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2400 - mae: 0.2192 - rmse: 0.2369 - val_loss: 0.3123 - val_mae: 0.2648 - val_rmse: 0.3123
# Epoch 20/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.2424 - mae: 0.2186 - rmse: 0.2410 - val_loss: 0.3138 - val_mae: 0.2619 - val_rmse: 0.3138
# Epoch 21/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2405 - mae: 0.2278 - rmse: 0.2357 - val_loss: 0.3066 - val_mae: 0.2681 - val_rmse: 0.3066
# Epoch 22/50
# 6/6 [==============================] - 0s 13ms/step - loss: 0.2401 - mae: 0.2201 - rmse: 0.2424 - val_loss: 0.3206 - val_mae: 0.2543 - val_rmse: 0.3206
# Epoch 23/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2388 - mae: 0.2122 - rmse: 0.2343 - val_loss: 0.3070 - val_mae: 0.2620 - val_rmse: 0.3070
# Epoch 24/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2357 - mae: 0.2223 - rmse: 0.2384 - val_loss: 0.3060 - val_mae: 0.2604 - val_rmse: 0.3060
# Epoch 25/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2342 - mae: 0.2193 - rmse: 0.2263 - val_loss: 0.3116 - val_mae: 0.2531 - val_rmse: 0.3116
# Epoch 26/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2391 - mae: 0.2026 - rmse: 0.2376 - val_loss: 0.3124 - val_mae: 0.2502 - val_rmse: 0.3124
# Epoch 27/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2295 - mae: 0.2080 - rmse: 0.2278 - val_loss: 0.2993 - val_mae: 0.2595 - val_rmse: 0.2993
# Epoch 28/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2300 - mae: 0.2188 - rmse: 0.2290 - val_loss: 0.3054 - val_mae: 0.2494 - val_rmse: 0.3054
# Epoch 29/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2350 - mae: 0.2012 - rmse: 0.2220 - val_loss: 0.3163 - val_mae: 0.2404 - val_rmse: 0.3163
# Epoch 30/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2324 - mae: 0.1957 - rmse: 0.2291 - val_loss: 0.3023 - val_mae: 0.2451 - val_rmse: 0.3023
# Epoch 31/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2303 - mae: 0.2141 - rmse: 0.2301 - val_loss: 0.2924 - val_mae: 0.2516 - val_rmse: 0.2924
# Epoch 32/50
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2246 - mae: 0.2102 - rmse: 0.2189 - val_loss: 0.3023 - val_mae: 0.2371 - val_rmse: 0.3023
# Epoch 33/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2237 - mae: 0.1937 - rmse: 0.2308 - val_loss: 0.2961 - val_mae: 0.2355 - val_rmse: 0.2961
# Epoch 34/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2292 - mae: 0.2132 - rmse: 0.2270 - val_loss: 0.2847 - val_mae: 0.2428 - val_rmse: 0.2847
# Epoch 35/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2283 - mae: 0.2049 - rmse: 0.2250 - val_loss: 0.3024 - val_mae: 0.2282 - val_rmse: 0.3024
# Epoch 36/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2273 - mae: 0.2051 - rmse: 0.2329 - val_loss: 0.2818 - val_mae: 0.2362 - val_rmse: 0.2818
# Epoch 37/50
# 6/6 [==============================] - 0s 17ms/step - loss: 0.2177 - mae: 0.1937 - rmse: 0.2467 - val_loss: 0.3040 - val_mae: 0.2260 - val_rmse: 0.3040
# Epoch 38/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2200 - mae: 0.1940 - rmse: 0.2176 - val_loss: 0.2791 - val_mae: 0.2295 - val_rmse: 0.2791
# Epoch 39/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2180 - mae: 0.2012 - rmse: 0.2187 - val_loss: 0.2824 - val_mae: 0.2229 - val_rmse: 0.2824
# Epoch 40/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2198 - mae: 0.1827 - rmse: 0.2191 - val_loss: 0.3035 - val_mae: 0.2209 - val_rmse: 0.3035
# Epoch 41/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2188 - mae: 0.1864 - rmse: 0.2175 - val_loss: 0.2724 - val_mae: 0.2194 - val_rmse: 0.2724
# Epoch 42/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2063 - mae: 0.1875 - rmse: 0.2073 - val_loss: 0.2959 - val_mae: 0.2172 - val_rmse: 0.2959
# Epoch 43/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2152 - mae: 0.1763 - rmse: 0.2012 - val_loss: 0.2826 - val_mae: 0.2155 - val_rmse: 0.2826
# Epoch 44/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2076 - mae: 0.1794 - rmse: 0.2073 - val_loss: 0.2719 - val_mae: 0.2134 - val_rmse: 0.2719
# Epoch 45/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2092 - mae: 0.1842 - rmse: 0.2112 - val_loss: 0.2768 - val_mae: 0.2114 - val_rmse: 0.2768
# Epoch 46/50
# 6/6 [==============================] - 0s 16ms/step - loss: 0.2042 - mae: 0.1751 - rmse: 0.1980 - val_loss: 0.2779 - val_mae: 0.2090 - val_rmse: 0.2779
# Epoch 47/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2088 - mae: 0.1770 - rmse: 0.2001 - val_loss: 0.2697 - val_mae: 0.2072 - val_rmse: 0.2697
# Epoch 48/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.2020 - mae: 0.1734 - rmse: 0.2251 - val_loss: 0.2772 - val_mae: 0.2057 - val_rmse: 0.2772
# Epoch 49/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2022 - mae: 0.1732 - rmse: 0.1961 - val_loss: 0.2727 - val_mae: 0.2041 - val_rmse: 0.2727
# Epoch 50/50
# 6/6 [==============================] - 0s 15ms/step - loss: 0.2062 - mae: 0.1715 - rmse: 0.2054 - val_loss: 0.2849 - val_mae: 0.2040 - val_rmse: 0.2849

# %%
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 662ms/step
# MAPA (Accuracy): 98.48%

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='ME')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
percentage_error = np.abs((y_test_inv - y_pred_inv) / y_test_inv) * 100

plt.figure(figsize=(12, 6))
plt.plot(test_dates, percentage_error, color='purple', label='Percentage Error')
plt.title('Percentage Error Over Time')
plt.xlabel('Date')
plt.ylabel('Percentage Error (%)')
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
