# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# Load and preprocess data
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
weekly_df = daily_df.resample('W', on='Order Date')['Total Profit'].sum().reset_index()
weekly_df.columns = ['Order Date', 'Total Profit']
weekly_df.set_index('Order Date', inplace=True)

# Remove outliers
Q1 = weekly_df['Total Profit'].quantile( 0.25)
Q3 = weekly_df['Total Profit'].quantile( 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
weekly_df = weekly_df[(weekly_df['Total Profit'] >= lower_bound) & 
                      (weekly_df['Total Profit'] <= upper_bound)]

# Train-test split
train_data, test_data = train_test_split(weekly_df, test_size= 0.2, shuffle=False)

# Scale data
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# Create sequences
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])  # The date corresponding to y
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# For training data
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

# For test data
X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data  .index,
    seq_length
)

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[ 0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[ 0], X_test.shape[1], 1))

# Build model
model = Sequential([
    Bidirectional(LSTM( 100, return_sequences=True), input_shape=(seq_length, 1)),
    BatchNormalization(),
    Dropout( 0.3),
    Bidirectional(LSTM( 100, return_sequences=True)),
    BatchNormalization(),
    Dropout( 0.3),
    Bidirectional(LSTM( 50)),
    BatchNormalization(),
    Dropout( 0.3),
    Dense( 50, activation='relu'),
    Dense( 1)
])

def  rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# Train model
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])

# Make predictions
y_pred = model.predict(X_test)

# Inverse scaling
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

# Calculate metrics
mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

# Plot with correct dates
plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Future predictions (next 12 weeks)
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)
    # Update sequence by removing oldest and adding new prediction
    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

# Inverse scale predictions
future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

# Generate future dates
last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='W')

# Plot actual, predicted, and future predicted values
plt.figure(figsize=(14, 7))

# Historical actual and predicted
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

# Future forecast
plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')

# MAPA annotation
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

# Plot details
plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Epoch 1/50
# 27/27 [==============================] - 11s 82ms/step - loss: 0.9695 - mae: 0.7902 - rmse: 0.9695 - val_loss: 0.4114 - val_mae: 0.3677 - val_rmse: 0.4188
# Epoch 2/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.6338 - mae: 0.5049 - rmse: 0.6338 - val_loss: 0.3956 - val_mae: 0.3511 - val_rmse: 0.4031
# Epoch 3/50
# 27/27 [==============================] - 1s 20ms/step - loss: 0.5392 - mae: 0.4372 - rmse: 0.5392 - val_loss: 0.4809 - val_mae: 0.4430 - val_rmse: 0.4873
# Epoch 4/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4974 - mae: 0.4060 - rmse: 0.4974 - val_loss: 0.4868 - val_mae: 0.4502 - val_rmse: 0.4927
# Epoch 5/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4607 - mae: 0.3795 - rmse: 0.4607 - val_loss: 0.4733 - val_mae: 0.4356 - val_rmse: 0.4791
# Epoch 6/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4159 - mae: 0.3287 - rmse: 0.4159 - val_loss: 0.3956 - val_mae: 0.3520 - val_rmse: 0.4010
# Epoch 7/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.3925 - mae: 0.3201 - rmse: 0.3925 - val_loss: 0.3178 - val_mae: 0.2674 - val_rmse: 0.3216
# Epoch 8/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.3827 - mae: 0.3076 - rmse: 0.3827 - val_loss: 0.2814 - val_mae: 0.2358 - val_rmse: 0.2854
# Epoch 9/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3578 - mae: 0.2832 - rmse: 0.3578 - val_loss: 0.2078 - val_mae: 0.1772 - val_rmse: 0.2132
# Epoch 10/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3397 - mae: 0.2731 - rmse: 0.3397 - val_loss: 0.2134 - val_mae: 0.1747 - val_rmse: 0.2212
# Epoch 11/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3236 - mae: 0.2633 - rmse: 0.3236 - val_loss: 0.2457 - val_mae: 0.2043 - val_rmse: 0.2520
# Epoch 12/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3042 - mae: 0.2402 - rmse: 0.3042 - val_loss: 0.2532 - val_mae: 0.2119 - val_rmse: 0.2539
# Epoch 13/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2941 - mae: 0.2371 - rmse: 0.2941 - val_loss: 0.1940 - val_mae: 0.1616 - val_rmse: 0.2000
# Epoch 14/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2875 - mae: 0.2337 - rmse: 0.2875 - val_loss: 0.1885 - val_mae: 0.1551 - val_rmse: 0.1986
# Epoch 15/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2733 - mae: 0.2203 - rmse: 0.2733 - val_loss: 0.1835 - val_mae: 0.1494 - val_rmse: 0.1950
# Epoch 16/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2539 - mae: 0.2080 - rmse: 0.2539 - val_loss: 0.1979 - val_mae: 0.1688 - val_rmse: 0.2064
# Epoch 17/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2452 - mae: 0.1974 - rmse: 0.2452 - val_loss: 0.1902 - val_mae: 0.1565 - val_rmse: 0.2000
# Epoch 18/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2542 - mae: 0.2034 - rmse: 0.2542 - val_loss: 0.1998 - val_mae: 0.1690 - val_rmse: 0.2054
# Epoch 19/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2404 - mae: 0.1954 - rmse: 0.2404 - val_loss: 0.2041 - val_mae: 0.1694 - val_rmse: 0.2102
# Epoch 20/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2296 - mae: 0.1872 - rmse: 0.2296 - val_loss: 0.1959 - val_mae: 0.1664 - val_rmse: 0.2016
# Epoch 21/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2369 - mae: 0.1914 - rmse: 0.2369 - val_loss: 0.2272 - val_mae: 0.1894 - val_rmse: 0.2299
# Epoch 22/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2369 - mae: 0.1910 - rmse: 0.2369 - val_loss: 0.1937 - val_mae: 0.1587 - val_rmse: 0.2009
# Epoch 23/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2163 - mae: 0.1742 - rmse: 0.2163 - val_loss: 0.2377 - val_mae: 0.1992 - val_rmse: 0.2388
# Epoch 24/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2277 - mae: 0.1852 - rmse: 0.2277 - val_loss: 0.1868 - val_mae: 0.1564 - val_rmse: 0.1939
# Epoch 25/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2206 - mae: 0.1735 - rmse: 0.2206 - val_loss: 0.2312 - val_mae: 0.1931 - val_rmse: 0.2329
# Epoch 26/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2160 - mae: 0.1754 - rmse: 0.2160 - val_loss: 0.2091 - val_mae: 0.1708 - val_rmse: 0.2146
# Epoch 27/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.2141 - mae: 0.1746 - rmse: 0.2141 - val_loss: 0.1970 - val_mae: 0.1645 - val_rmse: 0.2039
# Epoch 28/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2023 - mae: 0.1634 - rmse: 0.2023 - val_loss: 0.1930 - val_mae: 0.1600 - val_rmse: 0.1984
# Epoch 29/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2027 - mae: 0.1645 - rmse: 0.2027 - val_loss: 0.1966 - val_mae: 0.1628 - val_rmse: 0.2044
# Epoch 30/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2152 - mae: 0.1728 - rmse: 0.2152 - val_loss: 0.2287 - val_mae: 0.1842 - val_rmse: 0.2397
# Epoch 31/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2038 - mae: 0.1649 - rmse: 0.2038 - val_loss: 0.1930 - val_mae: 0.1589 - val_rmse: 0.2006
# Epoch 32/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.2084 - mae: 0.1711 - rmse: 0.2084 - val_loss: 0.1900 - val_mae: 0.1579 - val_rmse: 0.1971
# Epoch 33/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2089 - mae: 0.1705 - rmse: 0.2089 - val_loss: 0.2218 - val_mae: 0.1802 - val_rmse: 0.2232
# Epoch 34/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.1987 - mae: 0.1592 - rmse: 0.1987 - val_loss: 0.1955 - val_mae: 0.1589 - val_rmse: 0.2020
# Epoch 35/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2032 - mae: 0.1612 - rmse: 0.2032 - val_loss: 0.1927 - val_mae: 0.1587 - val_rmse: 0.1988
# Epoch 36/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.1989 - mae: 0.1615 - rmse: 0.1989 - val_loss: 0.1885 - val_mae: 0.1534 - val_rmse: 0.1965
# Epoch 37/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1977 - mae: 0.1593 - rmse: 0.1977 - val_loss: 0.1864 - val_mae: 0.1553 - val_rmse: 0.1943
# Epoch 38/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1936 - mae: 0.1595 - rmse: 0.1936 - val_loss: 0.1865 - val_mae: 0.1536 - val_rmse: 0.1940
# Epoch 39/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1896 - mae: 0.1540 - rmse: 0.1896 - val_loss: 0.1817 - val_mae: 0.1514 - val_rmse: 0.1879
# Epoch 40/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1914 - mae: 0.1561 - rmse: 0.1914 - val_loss: 0.1930 - val_mae: 0.1618 - val_rmse: 0.1996
# Epoch 41/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.2009 - mae: 0.1648 - rmse: 0.2009 - val_loss: 0.1964 - val_mae: 0.1635 - val_rmse: 0.2020
# Epoch 42/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1908 - mae: 0.1562 - rmse: 0.1908 - val_loss: 0.1944 - val_mae: 0.1625 - val_rmse: 0.2002
# Epoch 43/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1953 - mae: 0.1572 - rmse: 0.1953 - val_loss: 0.1996 - val_mae: 0.1624 - val_rmse: 0.2029
# Epoch 44/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2049 - mae: 0.1601 - rmse: 0.2049 - val_loss: 0.1921 - val_mae: 0.1522 - val_rmse: 0.2013
# Epoch 45/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.1924 - mae: 0.1577 - rmse: 0.1924 - val_loss: 0.1818 - val_mae: 0.1494 - val_rmse: 0.1892
# Epoch 46/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1949 - mae: 0.1579 - rmse: 0.1949 - val_loss: 0.2058 - val_mae: 0.1716 - val_rmse: 0.2116
# Epoch 47/50
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1969 - mae: 0.1563 - rmse: 0.1969 - val_loss: 0.1909 - val_mae: 0.1594 - val_rmse: 0.1976
# Epoch 48/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1989 - mae: 0.1585 - rmse: 0.1989 - val_loss: 0.1808 - val_mae: 0.1512 - val_rmse: 0.1876
# Epoch 49/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1987 - mae: 0.1594 - rmse: 0.1987 - val_loss: 0.1803 - val_mae: 0.1462 - val_rmse: 0.1863
# Epoch 50/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.1948 - mae: 0.1598 - rmse: 0.1948 - val_loss: 0.1964 - val_mae: 0.1633 - val_rmse: 0.2020
# 4/4 [==============================] - 1s 9ms/step
# MAPA (Accuracy): 99.32%
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
