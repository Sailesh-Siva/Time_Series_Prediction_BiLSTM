# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Bidirectional, LSTM, Dropout, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_percentage_error
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("sales_5000000.csv")
df = df[['Order Date', 'Total Profit']] 
df['Order Date'] = pd.to_datetime(df['Order Date'])
daily_df = df.groupby('Order Date')['Total Profit'].sum().reset_index()
weekly_df = daily_df.resample('W', on='Order Date')['Total Profit'].sum().reset_index()
weekly_df.columns = ['Order Date', 'Total Profit']
weekly_df.set_index('Order Date', inplace=True)

# %%
Q1 = weekly_df['Total Profit'].quantile( 0.25)
Q3 = weekly_df['Total Profit'].quantile( 0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
weekly_df = weekly_df[(weekly_df['Total Profit'] >= lower_bound) & 
                      (weekly_df['Total Profit'] <= upper_bound)]

# %%
train_data, test_data = train_test_split(weekly_df, test_size= 0.2, shuffle=False)

# %%
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[["Total Profit"]])
test_scaled = scaler.transform(test_data[["Total Profit"]])
train_data["Total Profit"] = train_scaled.astype(float)
test_data["Total Profit"] = test_scaled.astype(float)

# %%
def create_sequences(data, dates, seq_length):
    X, y, seq_dates = [], [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
        seq_dates.append(dates[i+seq_length])
    return np.array(X), np.array(y), np.array(seq_dates)

seq_length = 12

# %%
X_train, y_train, train_dates = create_sequences(
    train_data["Total Profit"].values,
    train_data.index,
    seq_length
)

X_test, y_test, test_dates = create_sequences(
    test_data["Total Profit"].values,
    test_data.index,
    seq_length
)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
model = Sequential([
    Bidirectional(LSTM( 100, return_sequences=True), input_shape=(seq_length, 1)),
    BatchNormalization(),
    Dropout(0.3),
    Bidirectional(LSTM( 100, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.3),
    Bidirectional(LSTM( 50)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(50, activation='relu'),
    Dense(1)
])

# %%
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_true - y_pred)))

# %%
model.compile(optimizer='adam', loss=rmse, metrics=['mae', rmse])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience= 100, restore_best_weights=True)
history = model.fit(X_train, y_train, epochs= 50, batch_size= 16, 
                    validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 27/27 [==============================] - 11s 90ms/step - loss: 1.5901 - mae: 1.3209 - rmse: 1.5901 - val_loss: 0.3567 - val_mae: 0.3069 - val_rmse: 0.3655
# Epoch 2/50
# 27/27 [==============================] - 1s 24ms/step - loss: 0.8461 - mae: 0.6834 - rmse: 0.8461 - val_loss: 0.3017 - val_mae: 0.2492 - val_rmse: 0.3109
# Epoch 3/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.7044 - mae: 0.5708 - rmse: 0.7044 - val_loss: 0.3665 - val_mae: 0.3182 - val_rmse: 0.3756
# Epoch 4/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.6155 - mae: 0.4915 - rmse: 0.6155 - val_loss: 0.4186 - val_mae: 0.3759 - val_rmse: 0.4262
# Epoch 5/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.5632 - mae: 0.4602 - rmse: 0.5632 - val_loss: 0.3450 - val_mae: 0.2949 - val_rmse: 0.3563
# Epoch 6/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.4941 - mae: 0.3989 - rmse: 0.4941 - val_loss: 0.3365 - val_mae: 0.2850 - val_rmse: 0.3497
# Epoch 7/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.4478 - mae: 0.3588 - rmse: 0.4478 - val_loss: 0.3474 - val_mae: 0.2940 - val_rmse: 0.3660
# Epoch 8/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.4218 - mae: 0.3384 - rmse: 0.4218 - val_loss: 0.4553 - val_mae: 0.4055 - val_rmse: 0.4761
# Epoch 9/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.3905 - mae: 0.3142 - rmse: 0.3905 - val_loss: 0.3205 - val_mae: 0.2684 - val_rmse: 0.3355
# Epoch 10/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.3753 - mae: 0.3029 - rmse: 0.3753 - val_loss: 0.2442 - val_mae: 0.2027 - val_rmse: 0.2524
# Epoch 11/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.3392 - mae: 0.2792 - rmse: 0.3392 - val_loss: 0.2742 - val_mae: 0.2268 - val_rmse: 0.2821
# Epoch 12/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3531 - mae: 0.2858 - rmse: 0.3531 - val_loss: 0.2647 - val_mae: 0.2166 - val_rmse: 0.2692
# Epoch 13/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.3302 - mae: 0.2647 - rmse: 0.3302 - val_loss: 0.3391 - val_mae: 0.2864 - val_rmse: 0.3485
# Epoch 14/50
# 27/27 [==============================] - 1s 23ms/step - loss: 0.3078 - mae: 0.2537 - rmse: 0.3078 - val_loss: 0.2030 - val_mae: 0.1725 - val_rmse: 0.2080
# Epoch 15/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.3011 - mae: 0.2422 - rmse: 0.3011 - val_loss: 0.2104 - val_mae: 0.1742 - val_rmse: 0.2179
# Epoch 16/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2833 - mae: 0.2322 - rmse: 0.2833 - val_loss: 0.2014 - val_mae: 0.1664 - val_rmse: 0.2081
# Epoch 17/50
# 27/27 [==============================] - 1s 20ms/step - loss: 0.2737 - mae: 0.2206 - rmse: 0.2737 - val_loss: 0.2189 - val_mae: 0.1884 - val_rmse: 0.2222
# Epoch 18/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2782 - mae: 0.2283 - rmse: 0.2782 - val_loss: 0.1925 - val_mae: 0.1578 - val_rmse: 0.2003
# Epoch 19/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2633 - mae: 0.2139 - rmse: 0.2633 - val_loss: 0.2038 - val_mae: 0.1627 - val_rmse: 0.2176
# Epoch 20/50
# 27/27 [==============================] - 1s 20ms/step - loss: 0.2458 - mae: 0.1915 - rmse: 0.2458 - val_loss: 0.2195 - val_mae: 0.1817 - val_rmse: 0.2268
# Epoch 21/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2522 - mae: 0.2035 - rmse: 0.2522 - val_loss: 0.2015 - val_mae: 0.1644 - val_rmse: 0.2093
# Epoch 22/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2329 - mae: 0.1921 - rmse: 0.2329 - val_loss: 0.2005 - val_mae: 0.1615 - val_rmse: 0.2096
# Epoch 23/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2386 - mae: 0.1924 - rmse: 0.2386 - val_loss: 0.2194 - val_mae: 0.1779 - val_rmse: 0.2294
# Epoch 24/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2289 - mae: 0.1846 - rmse: 0.2289 - val_loss: 0.2034 - val_mae: 0.1738 - val_rmse: 0.2110
# Epoch 25/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2239 - mae: 0.1834 - rmse: 0.2239 - val_loss: 0.1924 - val_mae: 0.1658 - val_rmse: 0.2015
# Epoch 26/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2361 - mae: 0.1945 - rmse: 0.2361 - val_loss: 0.1897 - val_mae: 0.1555 - val_rmse: 0.1991
# Epoch 27/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2290 - mae: 0.1832 - rmse: 0.2290 - val_loss: 0.1939 - val_mae: 0.1630 - val_rmse: 0.2016
# Epoch 28/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2180 - mae: 0.1761 - rmse: 0.2180 - val_loss: 0.1913 - val_mae: 0.1583 - val_rmse: 0.2022
# Epoch 29/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2220 - mae: 0.1794 - rmse: 0.2220 - val_loss: 0.2361 - val_mae: 0.1954 - val_rmse: 0.2439
# Epoch 30/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2121 - mae: 0.1725 - rmse: 0.2121 - val_loss: 0.2034 - val_mae: 0.1670 - val_rmse: 0.2093
# Epoch 31/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2131 - mae: 0.1686 - rmse: 0.2131 - val_loss: 0.1971 - val_mae: 0.1593 - val_rmse: 0.2029
# Epoch 32/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2159 - mae: 0.1758 - rmse: 0.2159 - val_loss: 0.2552 - val_mae: 0.2164 - val_rmse: 0.2621
# Epoch 33/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2129 - mae: 0.1726 - rmse: 0.2129 - val_loss: 0.2039 - val_mae: 0.1690 - val_rmse: 0.2113
# Epoch 34/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2112 - mae: 0.1719 - rmse: 0.2112 - val_loss: 0.2379 - val_mae: 0.1935 - val_rmse: 0.2513
# Epoch 35/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2128 - mae: 0.1723 - rmse: 0.2128 - val_loss: 0.1934 - val_mae: 0.1576 - val_rmse: 0.2033
# Epoch 36/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2228 - mae: 0.1813 - rmse: 0.2228 - val_loss: 0.1868 - val_mae: 0.1512 - val_rmse: 0.1974
# Epoch 37/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2240 - mae: 0.1817 - rmse: 0.2240 - val_loss: 0.2257 - val_mae: 0.1843 - val_rmse: 0.2352
# Epoch 38/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2008 - mae: 0.1616 - rmse: 0.2008 - val_loss: 0.1846 - val_mae: 0.1517 - val_rmse: 0.1918
# Epoch 39/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2057 - mae: 0.1682 - rmse: 0.2057 - val_loss: 0.1905 - val_mae: 0.1584 - val_rmse: 0.1985
# Epoch 40/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2014 - mae: 0.1645 - rmse: 0.2014 - val_loss: 0.1907 - val_mae: 0.1640 - val_rmse: 0.1987
# Epoch 41/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2017 - mae: 0.1642 - rmse: 0.2017 - val_loss: 0.1880 - val_mae: 0.1526 - val_rmse: 0.1917
# Epoch 42/50
# 27/27 [==============================] - 1s 22ms/step - loss: 0.2013 - mae: 0.1612 - rmse: 0.2013 - val_loss: 0.2049 - val_mae: 0.1641 - val_rmse: 0.2113
# Epoch 43/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2048 - mae: 0.1688 - rmse: 0.2048 - val_loss: 0.1888 - val_mae: 0.1541 - val_rmse: 0.1944
# Epoch 44/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1844 - mae: 0.1529 - rmse: 0.1844 - val_loss: 0.1879 - val_mae: 0.1528 - val_rmse: 0.1914
# Epoch 45/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1994 - mae: 0.1628 - rmse: 0.1994 - val_loss: 0.1914 - val_mae: 0.1622 - val_rmse: 0.1980
# Epoch 46/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1973 - mae: 0.1601 - rmse: 0.1973 - val_loss: 0.2011 - val_mae: 0.1599 - val_rmse: 0.2065
# Epoch 47/50
# 27/27 [==============================] - 1s 20ms/step - loss: 0.2057 - mae: 0.1664 - rmse: 0.2057 - val_loss: 0.1911 - val_mae: 0.1564 - val_rmse: 0.1964
# Epoch 48/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.1996 - mae: 0.1620 - rmse: 0.1996 - val_loss: 0.1942 - val_mae: 0.1591 - val_rmse: 0.2010
# Epoch 49/50
# 27/27 [==============================] - 1s 20ms/step - loss: 0.1955 - mae: 0.1572 - rmse: 0.1955 - val_loss: 0.1960 - val_mae: 0.1676 - val_rmse: 0.2026
# Epoch 50/50
# 27/27 [==============================] - 1s 21ms/step - loss: 0.2007 - mae: 0.1633 - rmse: 0.2007 - val_loss: 0.2001 - val_mae: 0.1646 - val_rmse: 0.2048

# %%
y_pred = model.predict(X_test)

y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred_inv = scaler.inverse_transform(y_pred)

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
mapa = (1 - mape / 100) * 100
print(f"MAPA (Accuracy): {mapa:.2f}%")

plt.figure(figsize=(14, 7))
plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')
plt.annotate(f'MAPA: {mapa:.2f}%', 
             xy=(0.05, 0.9), xycoords='axes fraction',
             bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.title('Actual vs Predicted Total Profit', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 1s 8ms/step
# MAPA (Accuracy): 99.31%

# %%
last_sequence = X_test[-1:]
future_preds = []
for _ in range(12):
    pred = model.predict(last_sequence)[0][0]
    future_preds.append(pred)

    last_sequence = np.append(last_sequence[:, 1:, :], [[[pred]]], axis=1)

future_preds = scaler.inverse_transform(np.array(future_preds).reshape(-1, 1))

last_date = test_dates[-1]
future_dates = pd.date_range(start=last_date + pd.Timedelta(weeks=1), periods=12, freq='W')

plt.figure(figsize=(12, 6))

plt.plot(test_dates, y_test_inv, 'b-', linewidth=2, label='Actual Values', alpha=0.7)
plt.plot(test_dates, y_pred_inv, 'r--', linewidth=2, label='Predicted Values')

plt.plot(future_dates, future_preds, 'g-.', linewidth=2, label='Future Forecast')


plt.title('Actual, Predicted, and Future Total Profit Forecast', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Total Profit')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
